# %% [markdown]
# ![Ignatius-cabecera.jpg](attachment:Ignatius-cabecera.jpg)

# %%
from IPython.display import Image
Image(filename="C:/Users/migue/Desktop/CUNEF/REPO/MasterDataScienceCUNEF/MachineLearning/ExploratoryDataAnalysis/data/im/tenor.gif")
